// %%
#!about
// Out:
// <table><tbody><tr><td><img src="......" width="125em"></img></td><td style="line-height:.8em"><p style="font-size:1.5em"><b>.NET Interactive</b></p><p>&#169; 2020 Microsoft Corporation</p><p><b>Version: </b>1.0.522904+cdfa48b2ea1a27dfe0f545c42a34fd3ec7119074</p><p><b>Library version: </b>1.0.0-beta.24229.4+cdfa48b2ea1a27dfe0f545c42a34fd3ec7119074</p><p><b>Build date: </b>2024-10-05T01:28:30.3244930Z</p><p><a href="https://github.com/dotnet/interactive">https://github.com/dotnet/interactive</a></p></td></tr></tbody></table>

// %%
// Install the ScottPlot NuGet package
#r "nuget:ScottPlot, 5.0.*"
open ScottPlot
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>ScottPlot, 5.0.39</span></li></ul></div></div>

// %%
open Microsoft.DotNet.Interactive.Formatting
open ScottPlot
open System.IO

Formatter.Register<Plot>(
    (fun (p: Plot) (w: TextWriter) -> 
        w.Write(p.GetImageHtml(400, 300))), 
    HtmlFormatter.MimeType
)

// %% [markdown]
// Source: https://scottplot.net/cookbook/5.0/Internationalization/

// %% [markdown]
// # Internationalization

// %% [markdown]
// ## Supported Font Detection
//
// ScottPlot comes with font detection methods which help identify the best installed font for displaying text which may contain international characters.

// %%
open ScottPlot

// Create a new plot
let myPlot = new Plot()

// Set titles in different languages with detected fonts
let chinese = "测试"
myPlot.Axes.Title.Label.Text <- chinese
myPlot.Axes.Title.Label.FontName <- Fonts.Detect(chinese)

let japanese = "試験"
myPlot.Axes.Left.Label.Text <- japanese
myPlot.Axes.Left.Label.FontName <- Fonts.Detect(japanese)

let korean = "테스트"
myPlot.Axes.Bottom.Label.Text <- korean
myPlot.Axes.Bottom.Label.FontName <- Fonts.Detect(korean)

myPlot
// Out:
// <img src="data:image/png;base64,..."></img>

// %% [markdown]
// ## Automatic Font Detection
//
// The Plot’s Style class contains a method which automatically sets the fonts of common plot objects to the font most likely able to display the characters they contain.

// %%
open ScottPlot

// Create a new plot
let myPlot = new Plot()

// Add signals with different phases
let sig1 = myPlot.Add.Signal(Generate.Sin(phase = 0.1))
let sig2 = myPlot.Add.Signal(Generate.Sin(phase = 0.2))
let sig3 = myPlot.Add.Signal(Generate.Sin(phase = 0.3))

// Set legend texts in different languages
sig1.LegendText <- "测试" // Chinese
sig2.LegendText <- "試験" // Japanese
sig3.LegendText <- "테스트" // Korean

// Show the legend
myPlot.ShowLegend()

// Set titles and labels in different languages
myPlot.Title("测试") // Chinese
myPlot.YLabel("試験") // Japanese
myPlot.XLabel("테스트") // Korean

// Automatically set font for each item based on its content
myPlot.Font.Automatic()

myPlot
// Out:
// <img src="data:image/png;base64,..."></img>
