// %%
#!about
// Out:
// <table><tbody><tr><td><img src="......" width="125em"></img></td><td style="line-height:.8em"><p style="font-size:1.5em"><b>.NET Interactive</b></p><p>&#169; 2020 Microsoft Corporation</p><p><b>Version: </b>1.0.522904+cdfa48b2ea1a27dfe0f545c42a34fd3ec7119074</p><p><b>Library version: </b>1.0.0-beta.24229.4+cdfa48b2ea1a27dfe0f545c42a34fd3ec7119074</p><p><b>Build date: </b>2024-10-05T01:28:30.3244930Z</p><p><a href="https://github.com/dotnet/interactive">https://github.com/dotnet/interactive</a></p></td></tr></tbody></table>

// %%
// Install the ScottPlot NuGet package
#r "nuget:ScottPlot, 5.0.*"
open ScottPlot
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>ScottPlot, 5.0.39</span></li></ul></div></div>
// Loading extensions from `C:\Users\0\.nuget\packages\skiasharp\2.88.8\interactive-extensions\dotnet\SkiaSharp.DotNet.Interactive.dll`

// %%
open Microsoft.DotNet.Interactive.Formatting
open ScottPlot
open System.IO

Formatter.Register<Plot>(
    (fun (p: Plot) (w: TextWriter) -> 
        w.Write(p.GetImageHtml(400, 300))), 
    HtmlFormatter.MimeType
)

// %% [markdown]
// Source: https://scottplot.net/cookbook/5.0/MultiAxis/

// %% [markdown]
// # Multiple Axes

// %% [markdown]
// ## Right Axis
//
// New plots have one axis on every side. Axes on the right and top are invisible by default. To use the right axis, make it visible, then tell a plottable to use it.

// %%
open ScottPlot

// Create a new plot
let myPlot = new Plot()

// Plot data with very different scales
let sig1 = myPlot.Add.Signal(Generate.Sin(mult = 0.01))
let sig2 = myPlot.Add.Signal(Generate.Cos(mult = 100.0))

// Tell each signal plot to use a different axis
sig1.Axes.YAxis <- myPlot.Axes.Left
sig2.Axes.YAxis <- myPlot.Axes.Right

// Add additional styling options to each axis
myPlot.Axes.Left.Label.Text <- "Left Axis"
myPlot.Axes.Right.Label.Text <- "Right Axis"
myPlot.Axes.Left.Label.ForeColor <- sig1.Color
myPlot.Axes.Right.Label.ForeColor <- sig2.Color

myPlot
// Out:
// <img src="data:image/png;base64,..."></img>

// %% [markdown]
// ## Multi-Axis
//
// Additional axes may be added to plots. Plottables are displayed using the coordinate system of the primary axes by default, but any plottable can be displayed using any X and Y axis.

// %%
open ScottPlot

// Create a new plot
let myPlot = new Plot()

// Plottables use the standard X and Y axes by default
let sig1 = myPlot.Add.Signal(Generate.Sin(51, mult = 0.01))
sig1.Axes.XAxis <- myPlot.Axes.Bottom // standard X axis
sig1.Axes.YAxis <- myPlot.Axes.Left   // standard Y axis
myPlot.Axes.Left.Label.Text <- "Primary Y Axis"

// Create a second axis and add it to the plot
let yAxis2 = myPlot.Axes.AddLeftAxis()

// Add a new plottable and tell it to use the custom Y axis
let sig2 = myPlot.Add.Signal(Generate.Cos(51, mult = 100))
sig2.Axes.XAxis <- myPlot.Axes.Bottom // standard X axis
sig2.Axes.YAxis <- yAxis2              // custom Y axis
yAxis2.LabelText <- "Secondary Y Axis"

myPlot
// Out:
// <img src="data:image/png;base64,..."></img>
