// %%
#!about
// Out:
// <table><tbody><tr><td><img src="......" width="125em"></img></td><td style="line-height:.8em"><p style="font-size:1.5em"><b>.NET Interactive</b></p><p>&#169; 2020 Microsoft Corporation</p><p><b>Version: </b>1.0.522904+cdfa48b2ea1a27dfe0f545c42a34fd3ec7119074</p><p><b>Library version: </b>1.0.0-beta.24229.4+cdfa48b2ea1a27dfe0f545c42a34fd3ec7119074</p><p><b>Build date: </b>2024-10-05T01:28:30.3244930Z</p><p><a href="https://github.com/dotnet/interactive">https://github.com/dotnet/interactive</a></p></td></tr></tbody></table>

// %%
// Install the ScottPlot NuGet package
#r "nuget:ScottPlot, 5.0.*"
open ScottPlot
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>ScottPlot, 5.0.39</span></li></ul></div></div>

// %%
open Microsoft.DotNet.Interactive.Formatting
open ScottPlot
open System.IO

Formatter.Register<Plot>(
    (fun (p: Plot) (w: TextWriter) -> 
        w.Write(p.GetImageHtml(400, 300))), 
    HtmlFormatter.MimeType
)

// %% [markdown]
// Source: https://scottplot.net/cookbook/5.0/Layout/

// %% [markdown]
// # Layout Options
//
// ## Frameless Plot
//
// How to create a plot containing only the data area and no axes.

// %%
open ScottPlot

// Create a new plot
let myPlot = new Plot()

// Add sine and cosine signals to the plot
myPlot.Add.Signal(Generate.Sin(51))
myPlot.Add.Signal(Generate.Cos(51))

// Make the data area cover the full figure
myPlot.Layout.Frameless()

// Set the data area background color
myPlot.DataBackground.Color <- Colors.WhiteSmoke

myPlot
// Out:
// <img src="data:image/png;base64,..."></img>

// %% [markdown]
// ## Fixed Padding
//
// The plot can be arranged to achieve a fixed amount of padding on each side of the data area

// %%
open ScottPlot

// Create a new plot
let myPlot = new Plot()

// Add sample data to the plot
myPlot.Add.Signal(Generate.Sin(51))
myPlot.Add.Signal(Generate.Cos(51))

// Use a fixed amount of pixel padding on each side
let padding = PixelPadding(100f, 50f, 100f, 50f)
myPlot.Layout.Fixed(padding)

// Darken the figure background to observe its dimensions
myPlot.FigureBackground.Color <- Colors.LightBlue
myPlot.DataBackground.Color <- Colors.White

myPlot
// Out:
// <img src="data:image/png;base64,..."></img>

// %% [markdown]
// ## Fixed Rectangle
//
// The plot can be arranged so the data is drawn inside a fixed rectangle defined in pixel units

// %%
open ScottPlot

// Create a new plot
let myPlot = new Plot()

// Add sample data to the plot
myPlot.Add.Signal(Generate.Sin(51))
myPlot.Add.Signal(Generate.Cos(51))

// Set the data area to render inside a fixed rectangle
let size = PixelSize(300, 200)
let offset = Pixel(50, 50)
let rect = PixelRect(size, offset)
myPlot.Layout.Fixed(rect)

// Darken the figure background to observe its dimensions
myPlot.FigureBackground.Color <- Colors.LightBlue
myPlot.DataBackground.Color <- Colors.White

myPlot
// Out:
// <img src="data:image/png;base64,..."></img>
